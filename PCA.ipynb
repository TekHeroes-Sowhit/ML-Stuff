# %%
## As the number of dimension increase it is called curses. It will have an impact on the accuracy

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from PIL import Image

# %%
Image.open(r"C:/Users/00824732/Desktop/new_one.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=748x280 at 0x2DB3505E9D0>

# %%
df_one=load_breast_cancer()

# %%
df_one.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df=pd.DataFrame(df['data'],columns=df['feature_names'])

# %% [markdown]
# ## PCA

# %%
## It will be difficult to visualize high dimensional data. we can use pca to find the first two principal componets and visualize the data  in the new two dimensional space with a single scatter plot

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
#mean=0 and sd=1

# %%
sd.fit(df)
# Out:
# StandardScaler()

# %%
scaled=data=sd.transform(df)

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(scaled)
# Out:
# PCA(n_components=2)

# %%
x_transform=pca.fit(scaled)

# %%
x_pca=pca.transform(scaled)

# %%
x_pca.shape
# Out:
# (569, 2)

# %%
## After reading the data first step is Scaling the data

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df_one['target'],cmap='plasma')
plt.xlabel('First PCA')
plt.ylabel('Second PCA')
plt.show()
