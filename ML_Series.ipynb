# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import collections
from datetime import datetime
# import itertools
# from sklearn.clustering import Kmeans
from sklearn.pipeline import Pipeline
import seaborn as sns
import numpy as np

# %%
from sklearn.

# %%
df=pd.read_csv('file:///C:/Users/00824732/Desktop/supermarket_sales%20.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,y_train,x_test,y_test=train_test_split()

# %% [markdown]
# ## Variance Inflation Factor

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.__get__numeric_data()

# %%
# %%capture
#gather features
features = "+".join(df.columns - ["annual_inc"])

# get y and X dataframes based on this regression:
y, X = dmatrices('annual_inc ~' + features, df, return_type='dataframe')

# %%
https://etav.github.io/python/vif_factor_python.html

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)

# %% [markdown]
# ## Feature selection using corelation

# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import scipy.stats  as stat

# %%
data=load_boston()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)
df["Medv"]=data.target

# %%
x=df.drop("Medv",axis=1)
y=df["Medv"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
corr=x_train.corr()
#sns.heatmap(corr,annot=True,cmap=plt.cm)

# %%
def corelations(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc [i,j])>threshold:
                 colname=corr_matrix.columns[i]
                 col_corr.add(colname)
    return col_corr

# %% [markdown]
# ## Bias and Variance

# %%
from mlxtend.evaluate import bias_variance_decomp
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression, Lasso
import warnings
warnings.filterwarnings('ignore')
#We will load the Boston house dataset for our example
from sklearn.datasets import load_boston
from sklearn import metrics
# From the library load the necessary rows & columns
X, y = load_boston(return_X_y=True)
# Split the dataset into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# Model definition
model_lr = LinearRegression()
# Estimation of bias and variance using bias_variance_decomp 
#Note here we are using loss as 'mse' and setting default bootstrap num_rounds to 200
mse, bias, var = bias_variance_decomp(model_lr, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=123)
y_pred=model_lr.predict(X_test)
# summarize results
print('MSE from bias_variance lib [avg expected loss]: %.3f' % mse)
print('Avg Bias: %.3f' % bias)
print('Avg Variance: %.3f' % var)
print('Mean Square error by Sckit-learn lib: %.3f' % metrics.mean_squared_error(y_test,y_pred))
# Out:
# MSE from bias_variance lib [avg expected loss]: 22.128
# Avg Bias: 20.522
# Avg Variance: 1.606
# Mean Square error by Sckit-learn lib: 22.069

# %%
# Imports PIL module 
from PIL import Image
# open method used to open different extension image file
im = Image.open(r"C:/Users/00824732/Desktop/newqq.PNG") 
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1027x447 at 0x18B7504EF40>

# %%
from PIL import Image
# open method used to open different extension image file
im = Image.open(r"C:/Users/00824732/Desktop/new.PNG") 
im
# file:///C:/Users/00824732/Desktop/under%20and%20overfitting.PNG
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=542x233 at 0x18B750E6A90>

# %%
### Linear Regression
### Logistic Regresio

# %%
## Feature selction  Dropping constant Features
## curse of dimensionality

# %%
import pandas as pd
data=pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]})

# %%
## Variance Threshold

# %%
from sklearn.feature_selection import VarianceThreshold
var_thresh=VarianceThreshold(threshold=0)
var_thresh.fit(data)
# Out:
# VarianceThreshold(threshold=0)

# %%
constact_columns=[column for column in data.columns if column not in data.columns[var_thresh.get_support()]]

# %%
var_thresh.get_support()
# Out:
# array([ True,  True,  True])

# %%
for feature in constact_columns:
    print(feature)

# %%
data.drop(constact_columns,axis=1)
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df=pd.read_csv(r'file:///C:/Users/00824732/Desktop/TSLA.csv')

# %%
vc=VarianceThreshold()

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2011-01-03  1.789333  1.800000  1.726667  1.774667   1.774667  19245000
# 1  2011-01-04  1.777333  1.796667  1.734667  1.778000   1.778000  17811000
# 2  2011-01-05  1.765333  1.793333  1.746000  1.788667   1.788667  21700500
# 3  2011-01-06  1.788667  1.866667  1.787333  1.858667   1.858667  30918000
# 4  2011-01-07  1.866667  1.905333  1.860000  1.882667   1.882667  33718500

# %%
x=df[['High', 'Open']]
y=df[['Volume']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
## variance threshold
var_thresh=VarianceThreshold()
var_thresh.fit(x_train)
# Out:
# VarianceThreshold()

# %%
var_thresh.get_support()
# Out:
# array([ True,  True])

# %%
## non constant features
sum(var_thresh.get_support())
# Out:
# 2

# %%
len(x_train.columns[var_thresh.get_support()])
# Out:
# 2

# %%
constact_columns=[columns for column in x_train.columns if column not in x_train.columns[var_thresh.get_support()]]

# %%
print(len(constact_columns))
# Out:
# 0

# %%
for columns in constact_columns:
    print(columns)

# %%
x_train.drop(constact_columns,axis=1)
# Out:
#             High        Open
# 1169   15.200000   15.195333
# 3000  196.250000  191.779999
# 2544  276.626678  270.813324
# 530     2.591333    2.563333
# 196     1.866667    1.816667
# ...          ...         ...
# 1783   23.463333   23.229334
# 2427  135.196671  131.659332
# 1144   17.962667   17.417999
# 1006   14.883333   14.858000
# 129     1.992667    1.992667
#
# [2268 rows x 2 columns]

# %% [markdown]
# ## Probability Ratio Encoding- Handling Categorical Feature

# %%
df.head()
# Out:
#    sex  embarked  alone  survived
# 0    1         0      0         0
# 1    0         1      0         1
# 2    0         0      1         1
# 3    0         0      0         1
# 4    1         0      1         0

# %% [markdown]
# ## Chi2 Statistical Analysis

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df=df[['sex','embarked','alone','survived']]

# %%
## Before chisquare we have to apply lable encoding
import numpy as np
df['sex']=np.where(df['sex']=="male",1,0)

# %%
ordinal_variable={k:i for i,k in enumerate(df['embarked'].unique(),0)}

# %%
df['embarked']=df['embarked'].map(ordinal_variable)

# %%
df['alone']=np.where(df['alone']==True,1,0)

# %%
## Train and Test split

# %%
df.columns
# Out:
# Index(['sex', 'embarked', 'alone', 'survived'], dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['sex','embarked']],df['survived'])

# %%
from sklearn.feature_selection import chi2

# %%
## It will return F-score and P value
f_p_values=chi2(x_train,y_train)

# %%
## lower the p values that significant the dataset
p_values=pd.Series(f_p_values[1])

# %%
p_values.index=x_train.columns

# %%
p_values
# Out:
# sex         7.567575e-17
# embarked    1.029723e-03
# dtype: float64

# %%
p_values.sort_index(ascending=True)
# Out:
# embarked    1.029723e-03
# sex         7.567575e-17
# dtype: float64

# %%
    ## sex is the most important column when compared to the output feature embarked

# %%
## Drop Features using Pearson Corelation

# %%
plt.figure(figsize=(12,2))
corr=x_train.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
def corelation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])> threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=corelation(x_train,0.7)

# %%
len(set(corr_features))
# Out:
# 0

# %%
x_train.drop(corr_features)
# Out:
#      sex  embarked
# 256    0         1
# 799    0         0
# 451    1         0
# 792    0         0
# 827    1         1
# ..   ...       ...
# 561    1         0
# 526    0         0
# 264    0         2
# 797    0         0
# 648    1         0
#
# [668 rows x 2 columns]

# %% [markdown]
# ## Feature Scaling

# %%
## Gaussian Transformation

# %%
# Imports PIL module 
from PIL import Image
# open method used to open different extension image file
im = Image.open(r"C:/Users/00824732/Desktop/Types.PNG") 
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=530x187 at 0x18B7F070D60>

# %%
## Log Transformation
import numpy as np
df['log']=np.log(df['survived'])
plot_data(df,'log')

# %%
## Reciprocal Transofmration
df['reci']=1/df.survived
plot_data(df,'reci')

# %%
import scipy.stats as stat
import pylab

# %%
## If we want to check if the feature is normally distrubuted or not.
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    df['alone'].hist()
    plt.subplot(1,2,2)
    stat.probplot(df['survived'],dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(df,'survived')

# %%
## Square root transformation
df['Sqrt']=df['survived']**(1/2)
plot_data(df,'sqrt')

# %%
## Exponential Transformation
df['expo']=df['survived']**(1/1.2)
plot_data(df,'expo')

# %%
## Boxcox transformation
from PIL import Image
# open method used to open different extension image file
im = Image.open(r"C:/Users/00824732/Desktop/boxcox1.PNG") 
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=682x229 at 0x18B7F170FD0>

# %%
df['Survived_boxcox'],parameter=stat.boxcox(df['survived'])
plot_data(df,'Survived_boxcox')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\00824732\Desktop\New folder (2)\ML_Series.ipynb Cell 87 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/00824732/Desktop/New%20folder%20%282%29/ML_Series.ipynb#Y165sZmlsZQ%3D%3D?line=0'>1</a> df['Survived_boxcox'],parameter=stat.boxcox(df['survived'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\stats\morestats.py:1064, in boxcox(x, lmbda, alpha, optimizer)
#    1061     raise ValueError("Data must not be constant.")
#    1063 if np.any(x <= 0):
# -> 1064     raise ValueError("Data must be positive.")
#    1066 if lmbda is not None:  # single transformation
#    1067     return special.boxcox(x, lmbda)
#
# ValueError: Data must be positive.

# %%
import math
import numpy as np
from scipy.stats import kstest
from scipy.stats import lognorm

# %%
np.random.seed(1)

#generate dataset that contains 1000 log-normal distributed values
lognorm_dataset = lognorm.rvs(s=.5, scale=math.exp(1), size=1000)

#perform Kolmogorov-Smirnov test for normality
kstest(lognorm_dataset, 'norm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\00824732\Desktop\ML_Series.ipynb Cell 89 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/00824732/Desktop/ML_Series.ipynb#Y154sZmlsZQ%3D%3D?line=0'>1</a> np.random.seed(1)
#       <a href='vscode-notebook-cell:/c%3A/Users/00824732/Desktop/ML_Series.ipynb#Y154sZmlsZQ%3D%3D?line=2'>3</a> #generate dataset that contains 1000 log-normal distributed values
#       <a href='vscode-notebook-cell:/c%3A/Users/00824732/Desktop/ML_Series.ipynb#Y154sZmlsZQ%3D%3D?line=3'>4</a> lognorm_dataset = lognorm.rvs(s=.5, scale=math.exp(1), size=1000)
#
# NameError: name 'np' is not defined

# %%
## Robust Scaler
# Imports PIL module 
from PIL import Image
# open method used to open different extension image file
im = Image.open(r"C:/Users/00824732/Desktop/robust.PNG") 
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=687x190 at 0x18B7EF70910>

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
rs.fit_transform(x_train)
# Out:
# array([[-1.,  1.],
#        [-1.,  0.],
#        [ 0.,  0.],
#        ...,
#        [-1.,  2.],
#        [-1.,  0.],
#        [ 0.,  0.]])
